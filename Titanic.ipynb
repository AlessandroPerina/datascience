# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic_data.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print "Male saved " + str( 100*df[ df.Sex == 'male' ]['Survived'].mean()) + "%"
print "Female saved " + str( 100*df[ df.Sex == 'female' ]['Survived'].mean()) + "%"
# Out:
# Male saved 18.8908145581%
# Female saved 74.2038216561%

# %%
Predicted =(df.Sex == 'female' ).map(int)
Predicted.index = df.PassengerId

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
A = df.count( 'Age' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-17739d83a6f3> in <module>()
# ----> 1 A = df.count( 'Age' )
#
# C:\Users\APerina\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\frame.pyc in count(self, axis, level, numeric_only)
#    3954         count : Series (or DataFrame if level specified)
#    3955         """
# -> 3956         axis = self._get_axis_number(axis)
#    3957         if level is not None:
#    3958             return self._count_level(level, axis=axis,
#
# C:\Users\APerina\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\generic.pyc in _get_axis_number(self, axis)
#     293                 pass
#     294         raise ValueError('No axis named {0} for object type {1}'
# --> 295                          .format(axis, type(self)))
#     296
#     297     def _get_axis_name(self, axis):
#
# ...

# %%
print A
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BCF1F28>]]
